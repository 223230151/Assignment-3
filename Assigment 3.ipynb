# %% [markdown]
# Credit Card Approvals
#
# Author : Bomikazi Tshalilanga(223230151)
# Date : 14 April 2023
# Source: Credit Card Approvals.xlsx
# Github url:https://github.com/223230151/Assignment-3

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns


CreditCardApproval_df = pd.read_excel(r'/home/f5384478/Documents/personal/Assignment 2/Credit Card Approvals.xlsx')
print(CreditCardApproval_df)
# Out:
#      Gender  Age   Debt  Married  BankCustomer         Industry Ethnicity  \
# 0         1   31      0        1           1.0      Industrials     White
# 1         0   59   4460        1           1.0        Materials     Black
# 2         0   25    500        1           1.0        Materials     Black
# 3         1   28   1540        1           1.0      Industrials     White
# 4         1   20   5625        1           1.0      Industrials     White
# ..      ...  ...    ...      ...           ...              ...       ...
# 685       1   21  10085        0           0.0        Education     Black
# 686       0   23    750        1           1.0           Energy     White
# 687       0   25  13500        0           0.0       Healthcare    Latino
# 688       1   18    205        1           1.0  ConsumerStaples     White
# 689       1   35   3375        1           1.0           Energy     Black
#
#      YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# ...

# %%
CreditCardApproval_df.drop(CreditCardApproval_df.columns[0], axis = 1, inplace =True)
CreditCardApproval_df.head()
# Out:
#    Age  Debt  Married  BankCustomer     Industry Ethnicity  YearsEmployed  \
# 0   31     0        1           1.0  Industrials     White           1.25
# 1   59  4460        1           1.0    Materials     Black           3.04
# 2   25   500        1           1.0    Materials     Black           1.50
# 3   28  1540        1           1.0  Industrials     White           3.75
# 4   20  5625        1           1.0  Industrials     White           1.71
#
#    PriorDefault  Employed  CreditScore  DriversLicense       Citizen  ZipCode  \
# 0             1         1            1               0       ByBirth      202
# 1             1         1            6               0       ByBirth       43
# 2             1         0            0               0       ByBirth      280
# 3             1         1            5               1       ByBirth      100
# 4             1         0            0               0  ByOtherMeans      120
#
#    Income  Approved
# 0       0         1
# ...

# %%
print(CreditCardApproval_df.size)
print(CreditCardApproval_df.shape)
# Out:
# 10350
# (690, 15)

# %%
CreditCardApproval_df[['Age','Debt','YearsEmployed','CreditScore','Income']].describe().round(2)
# Out:
#           Age      Debt  YearsEmployed  CreditScore     Income
# count  690.00    690.00         690.00       690.00     690.00
# mean    31.56   4758.72           2.22         2.40    1017.39
# std     11.86   4978.16           3.35         4.86    5210.10
# min     14.00      0.00           0.00         0.00       0.00
# 25%     23.00   1000.00           0.16         0.00       0.00
# 50%     28.00   2750.00           1.00         0.00       5.00
# 75%     38.00   7207.50           2.62         3.00     395.50
# max     80.00  28000.00          28.50        67.00  100000.00

# %%
selected_columns = ['Age', 'Debt', 'YearsEmployed', 'CreditScore', 'Income']
selected_data = CreditCardApproval_df[selected_columns]

range_ = selected_data.max() - selected_data.min()
print('The range is:\n',range_)
# Out:
# The range is:
#  Age                  66.0
# Debt              28000.0
# YearsEmployed        28.5
# CreditScore          67.0
# Income           100000.0
# dtype: float64

# %%
variance = CreditCardApproval_df[['Age', 'Debt', 'YearsEmployed', 'CreditScore', 'Income']].var().round(2)
print('Variance for :\n',variance)
# Out:
# Variance for :
#  Age                   140.63
# Debt             24782109.33
# YearsEmployed          11.20
# CreditScore            23.65
# Income           27145169.08
# dtype: float64

# %%
CreditCardApproval_df['Ethnicity'].replace(['Black','White','Latin0'],[1,2,3], inplace=True)
CreditCardApproval_df.head()
# Out:
#    Age  Debt  Married  BankCustomer     Industry Ethnicity  YearsEmployed  \
# 0   31     0        1           1.0  Industrials         2           1.25
# 1   59  4460        1           1.0    Materials         1           3.04
# 2   25   500        1           1.0    Materials         1           1.50
# 3   28  1540        1           1.0  Industrials         2           3.75
# 4   20  5625        1           1.0  Industrials         2           1.71
#
#    PriorDefault  Employed  CreditScore  DriversLicense       Citizen  ZipCode  \
# 0             1         1            1               0       ByBirth      202
# 1             1         1            6               0       ByBirth       43
# 2             1         0            0               0       ByBirth      280
# 3             1         1            5               1       ByBirth      100
# 4             1         0            0               0  ByOtherMeans      120
#
#    Income  Approved
# 0       0         1
# ...

# %%
not_approved = CreditCardApproval_df['Approved'].value_counts()[0]
approved = CreditCardApproval_df['Approved'].value_counts()[1]
values = [approved, not_approved]
labels = ['Approved', 'Not Approved']

fig, ax = plt.subplots()
ax.pie(values, labels=labels, autopct='%1.1f%%')
ax.set_title('The Credit Card Approvals')
plt.show()

# %%
sns.boxplot(y= CreditCardApproval_df['Age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(y= CreditCardApproval_df['Debt'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(y= CreditCardApproval_df['YearsEmployed'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(y= CreditCardApproval_df['CreditScore'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
CreditCardApproval_df.boxplot(column=['Age','Debt','YearsEmployed','CreditScore','Income'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Mode:\n',CreditCardApproval_df[['Age','Debt','Ethnicity','YearsEmployed','CreditScore','Income']].mode())
# Out:
# Mode:
#     Age  Debt Ethnicity  YearsEmployed  CreditScore  Income
# 0   23  1500         2            0.0            0       0

# %%
print('Geometric: mean \n',stats.gmean(CreditCardApproval_df['Age']))
# Out:
# Geometric: mean
#  29.63137968747297

# %%
data = CreditCardApproval_df[['Age','Debt','YearsEmployed','CreditScore','Income']]
k = data.apply(stats.kurtosis)
k=round(k,2)
print('Kurtosis:\n', k,)
# Out:
# Kurtosis:
#  Age                1.20
# Debt               2.25
# YearsEmployed     11.11
# CreditScore       50.45
# Income           213.11
# dtype: float64

# %%
skewness = CreditCardApproval_df[['Age','Debt','YearsEmployed','CreditScore','Income']].skew()
skewness =round(skewness,2)

print("Skewness:\n", skewness)
# Out:
# Skewness:
#  Age               1.17
# Debt              1.49
# YearsEmployed     2.89
# CreditScore       5.15
# Income           13.14
# dtype: float64

# %%
def plot_skewness(CreditCardApproval_df, Age):
    sns.displot(data=CreditCardApproval_df, x='Age', kde=True)
    plt.title(f'Skewness plot of Age')
    plt.show()
plot_skewness(CreditCardApproval_df, 'Age')

# %%
def plot_skewness(CreditCardApproval_df, Age):
    sns.displot(data=CreditCardApproval_df, x='Debt', kde=True)
    plt.title(f'Skewness plot of Debt')
    plt.show()
plot_skewness(CreditCardApproval_df, 'Debt')

# %%
def plot_skewness(CreditCardApproval_df, YearsEmployed):
    sns.displot(data=CreditCardApproval_df, x='YearsEmployed', kde=True)
    plt.title(f'Skewness plot of YearsEmployed')
    plt.show()
plot_skewness(CreditCardApproval_df, 'YearsEmployed')

# %%
def plot_skewness(CreditCardApproval_df, CreditScore):
    sns.displot(data=CreditCardApproval_df, x='CreditScore', kde=True)
    plt.title(f'Skewness plot of CreditScore')
    plt.show()
plot_skewness(CreditCardApproval_df, 'CreditScore')

# %%
def plot_skewness(CreditCardApproval_df, Income):
    sns.displot(data=CreditCardApproval_df, x='Income', kde=True)
    plt.title(f'Skewness plot of Income')
    plt.show()
plot_skewness(CreditCardApproval_df, 'Income')

# %%
f, axes = plt.subplots(2, 2, figsize=(15, 7), sharex=False)
sns.violinplot(CreditCardApproval_df.iloc[:,1], color="skyblue", ax=axes[0,0])
axes[0,0].set_xlabel('Age')
sns.violinplot(CreditCardApproval_df.iloc[:,2], color="olive", ax=axes[0,1])
axes[0,1].set_xlabel('Debt')
sns.violinplot(CreditCardApproval_df.iloc[:,7], color="gold", ax=axes[1,0])
axes[1,0].set_xlabel('YearsEmployed')
sns.violinplot(CreditCardApproval_df.iloc[:,-2], color="teal", ax=axes[1,1])
axes[1,1].set_xlabel('Income')
plt.show()

# %%
standard_deviation = CreditCardApproval_df[['Age','Debt','YearsEmployed','CreditScore','Income']].std()
total_Sum = CreditCardApproval_df['Age'].count()
standard_error = standard_deviation/np.sqrt(total_Sum)
print("standard_error:\n", standard_error)
# Out:
# standard_error:
#  Age                0.451451
# Debt             189.515436
# YearsEmployed      0.127400
# CreditScore        0.185129
# Income           198.345216
# dtype: float64

# %%
correlation = CreditCardApproval_df['Age'].corr(CreditCardApproval_df['CreditScore'])

print('Correlation between Age and CreditScore:', correlation)
# Out:
# Correlation between Age and CreditScore: 0.18789834435189426

# %%
plt.scatter(CreditCardApproval_df['Age'],CreditCardApproval_df['CreditScore'])
plt.title("Scatter Plot of Age vs. CreditScore")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = CreditCardApproval_df['YearsEmployed'].corr(CreditCardApproval_df['CreditScore'])

print('Correlation between YearsEmployed and CreditScore:', correlation)
# Out:
# Correlation between YearsEmployed and CreditScore: 0.322329667906177

# %%
plt.scatter(CreditCardApproval_df['YearsEmployed'],CreditCardApproval_df['CreditScore'])
plt.title("Scatter Plot of YearsEmployed vs. CreditScore")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = CreditCardApproval_df['Debt'].corr(CreditCardApproval_df['CreditScore'])

print('Correlation between Debt and CreditScore:', correlation)
# Out:
# Correlation between Debt and CreditScore: 0.2712067392584301

# %% [markdown]
# plt.scatter(CreditCardApproval_df['Debt'],CreditCardApproval_df['CreditScore'])
# plt.title("Scatter Plot of Debt vs. CreditScore")
# plt.show

# %%
f, ax = plt.subplots(figsize=(14,9))
corr = CreditCardApproval_df[['Age','Debt','YearsEmployed','CreditScore','Income']].corr()
sns.heatmap(corr, cmap='PiYG', annot=True, fmt='.2f', ax=ax)
ax.set_title('Correlation Matrix Plot For Credit Card Approvals')
plt.show()

# %% [markdown]
# The Conclusions From The Descriptive Statistics
#
#
# Age
#
# The average age of applicants is 31.56 years, with a standard deviation of 11.86 years. The youngest applicant was 14 years old, while the oldest was 80 years old. This information can be used to assess the possible risk of granting a credit card application based on the applicant's age. The range for age is 66 indicating that the is more variability in the age variable data. The mode of age is 23, indicating that the people with the age of 23 years old are the most that applied for credit card.The median for age is 28 meaning that 50% of the people applying for credit card are younger or are 28 years old and the other 50% of people are older than or are 28 years of age. The variance for age is 140.63, which is relatively small compared to the other variables in the dataset. This suggests that the age distribution of the applicants is relatively concentrated around the mean age of 31.56 years
#
# The Skewness for age is 1.17, indicating that the distribution for the age is highly skewed to the right meaning that most people applying for credit card are 28 years old or older and suggests that there are more older applicants than younger applicants. The kurtosis for the age is 1.22 indicating that the distribution tails are shorter and thinner, meaning outliers are infrequent in the distribution.
#
# We can see the evidence of the skewness and kurtosis values in the Age distribution plots, even the numbers (statistic for skewness and kurtosis) validate what we can see in the plots
#
#
#
# Debt
#
# The average debt of applicants is 4758.72, with a standard deviation of 4978.16.  The range for debt is 28000 indicating that the is more variability in the debt variable data, this indicates that some applicants have a large amount of debt, which may affect their creditworthiness. The mode of debt is 1500, indicating that most people's debt is 1500.The variance for debt is exceptionally large, at 24782109.33, this indicates that the debt amounts for the applicants are very spread out, with some applicants having much higher debt amounts than others. This may suggest that some applicants may have difficulty repaying their debts.
#
#
#
# The skewness for debt is ,1.49 indicating that the distribution is positively skewed,it is skewed to the right,this suggests that there are more applicants with higher debt amounts than lower debt amounts.The kurtosis for debt is 2.25, which is moderately higher than the value of 3 for a normal distribution. This indicates that the distribution of debt has a slightly fatter tail than a normal distribution. This suggest that there are some applicants with very high debt amounts, which could pose a higher risk for approving a credit card.
#
# We can see the evidence of the skewness and kurtosis values in the Debt distribution plots, even the numbers (statistic for skewness and kurtosis) validate what we can see in the plots.
#
#
#
# YearsEmployed
#
# The average length of employment is 2.22 years, with a standard deviation of 3.35 years, which indicates that the number of years employed by applicants is relatively spread out from the mean. The range of the number of years employed is from 0 to 28.50, this suggests that some applicants have recently started working or may have gaps in their employment history. The variance for the number of years employed is 11.20, which is relatively small compared to the other variables, this suggests that the distribution of employment duration is concentrated around the mean of 2.22 years.
#
# The skewness for the number of years employed is 2.89, indicating that the distribution of the years employed is positively skewed to the right, it is highly skewed, this suggests that there are more applicants with longer employment durations than shorter ones.
#
# The kurtosis for the number of years employed is very high at 11.11. This indicates that the distribution of employment duration has a much fatter tail than a normal distribution. This may suggest that there are some applicants who have been employed for a much longer duration than others, which could be an important factor in assessing creditworthiness.
#
# The years employed distribution plot also validate these values.
#
#
#
# CreditScore
#
# The average credit score of applicants is 2.40, with a standard deviation of 4.86. The range of credit scores is from 0 to 67, a low credit score may indicate that an applicant has a higher risk of failing to pay their debts. The variance for credit score is 23.65, which is moderately large. This indicates that the credit scores for the applicants are spread out, with some applicants having much lower credit scores than others.
#
# The skewness for the credit score is 5.15, indicating that its distribution is positively skewed to the right, it is highly skewed, this suggests that there are more applicants with high credit scores than low credit scores.
#
# The kurtosis for income is also very high at 213.11. This suggests that the distribution of income has a very fat tail, indicating that there may be a small number of applicants with very high incomes that are significantly different from the majority of the applicants.
#
#
# Income
#
# The average income of applicants is 1017.39, with a standard deviation of 5210.10. The range of income is from 0 to 100000. The high standard deviation and the large difference between the mean and the median suggest that there may be some outliers in the income data. This information can be used to assess the applicant's ability to repay their debt. The variance for income is very large, at 27145169.08. This suggests that the income levels for the applicants are very spread out, with some applicants having much higher incomes than others. This may indicate that some applicants have a higher ability to repay their debts.
#
# The skewness for income is 13.14, which indicates that the income distribution is highly skewed to the right. This suggests that there are more applicants with high incomes than low incomes.
#
# The kurtosis for income is also very high at 213.11. This suggests that the distribution of income has a very fat tail, indicating that there may be a small number of applicants with very high incomes that are significantly different from the majority of the applicants.
#
#
#
# All this information from different variables(Age,Debt,YearsEmployed,CreditScore,and Income) can help with Approving the Credit Cards applications to make informed decisions and to assess the level of risk associated with each applicant.

# %% [markdown]
# Reflections on your learnings
#
# I learnt that both Python provides a more powerful and flexible environment for data analysis and statistics compared to Excel, and Excel requires you to choose the data you want to run calculations under before executing the output, however in Python, you just utilize the dataset variable declared and call the particular column you want to perform your computations using that dataset variable. When making graphs and charts, Python provides more variety of visualization tools like Matplotlib, Seaborn, and Plotly ,that allow for more customisation and flexibility.
#
# Flexibility: When using Python, it was more flexible because I could create custom functions and scripts to perform specific analyses for the data, python produce more complex visualizations e.g., the violin plot that can be used to find or show outliers. While Excel provided me with pre-built functions and tools for simple statistical analysis but has restrictions on customisation and more complex analysis.
#
# Scalability: Python can handle massive data and carry out calculations more quickly than Excel, Python is better when showing complicated analysis.
#
# Integration with other tools: When using Python, I could import libraries and tools for manipulating, analysing, and visualising data, such as NumPy, Pandas, and Matplotlib, etc. and integrated data analysis experience.
#
# I can use Python if I want to perform complex analyses on large datasets with a high degree of flexibility and customisation, then I can use Excel when I need to quickly run simple analytics on smaller dataset.
#
# I would start by looking for a larger dataset than the one I am using and ensure that I completely understand it to determine which statistics to focus more on,I would also study more or do short course about doing complex analysis, and learn more about using Python and Jupyter notebook .Lastly, I would learn more about using visualising data such as NumPy, Pandas), if I could do this assignment over.
#
# The gaps in my programming and stats knowledge are:
#
# Insufficient knowledge of data preparation, cleaning, and visualization methods.
#
# inadequate knowledge of machine learning methods and algorithms.
#
# Lastly, lack of knowledge of ethical issues and appropriate procedures in data analysis and reporting.
